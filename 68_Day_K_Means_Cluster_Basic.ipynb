# %% [markdown]
# <a href="https://colab.research.google.com/github/adityayadav4507/100Days_of_ML/blob/main/68_Day_K_Means_Cluster_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/student_clustering.csv')
df
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
plt.scatter(df['cgpa'],df['iq'],cmap='viridis')
plt.xlabel('cgpa')
plt.ylabel('iq')
plt.show()

# %%
from sklearn.cluster import KMeans

wcss=[]

for i in range(1,10):
  km=KMeans(n_clusters=i,random_state=0)
  km.fit(df[['cgpa','iq']])
  wcss.append(km.inertia_)

wcss
# Out:
# [29957.898287999997,
#  4184.141269999999,
#  2503.3975810000015,
#  681.9696600000001,
#  530.4298616986187,
#  420.74846722383296,
#  385.4319788055321,
#  294.1172663037923,
#  204.41701717062713]

# %%
plt.plot(range(1,10),wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
X=df.iloc[:,:].values
km=KMeans(n_clusters=3,random_state=0)
y_predicted=km.fit_predict(X)
y_predicted
# Out:
# array([1, 2, 1, 1, 2, 2, 1, 0, 2, 1, 1, 2, 1, 1, 2, 1, 2, 1, 2, 2, 1, 1,
#        1, 1, 1, 1, 1, 0, 1, 2, 0, 2, 0, 2, 1, 1, 0, 2, 1, 2, 1, 1, 1, 1,
#        0, 0, 1, 2, 0, 2, 1, 1, 0, 1, 0, 2, 2, 0, 2, 0, 2, 1, 1, 0, 1, 0,
#        1, 1, 2, 1, 2, 0, 1, 1, 2, 0, 2, 0, 1, 1, 1, 0, 2, 1, 0, 1, 0, 2,
#        0, 2, 0, 0, 1, 1, 1, 1, 0, 1, 1, 0, 2, 1, 1, 0, 1, 1, 1, 1, 0, 0,
#        1, 0, 2, 2, 1, 0, 1, 2, 0, 1, 1, 2, 1, 0, 1, 1, 1, 2, 1, 1, 1, 2,
#        1, 1, 2, 0, 2, 1, 1, 1, 1, 1, 2, 1, 1, 0, 1, 0, 2, 1, 0, 1, 0, 0,
#        1, 1, 2, 0, 2, 1, 1, 0, 2, 1, 0, 1, 2, 1, 1, 0, 0, 2, 0, 1, 1, 1,
#        0, 2, 1, 0, 0, 2, 2, 2, 1, 1, 1, 1, 0, 2, 1, 1, 1, 1, 1, 1, 0, 2,
#        2, 0], dtype=int32)

# %%
X[y_predicted==0] # point which classified in 0 cluster
# Out:
# array([[  8.8 , 115.  ],
#        [  9.18, 119.  ],
#        [  8.86, 117.  ],
#        [  8.83, 118.  ],
#        [  8.56, 118.  ],
#        [  8.96, 116.  ],
#        [  8.78, 116.  ],
#        [  8.45, 119.  ],
#        [  8.79, 116.  ],
#        [  8.81, 115.  ],
#        [  8.88, 115.  ],
#        [  9.07, 117.  ],
#        [  8.92, 118.  ],
#        [  8.75, 113.  ],
#        [  8.71, 116.  ],
#        [  8.86, 118.  ],
#        [  9.3 , 117.  ],
#        [  9.01, 121.  ],
#        [  8.97, 116.  ],
#        [  9.  , 117.  ],
#        [  8.76, 117.  ],
#        [  8.78, 117.  ],
#        [  9.23, 114.  ],
#        [  9.03, 118.  ],
#        [  9.13, 118.  ],
#        [  8.91, 119.  ],
#        [  8.98, 118.  ],
#        [  9.03, 118.  ],
#        [  8.86, 117.  ],
#        [  8.89, 118.  ],
#        [  8.97, 117.  ],
#        [  8.72, 119.  ],
#        [  8.93, 118.  ],
#        [  8.58, 118.  ],
#        [  8.94, 117.  ],
#        [  8.6 , 117.  ],
#        [  8.77, 117.  ],
# ...

# %%
X[y_predicted==0,0] # 0th cluster point of x axis
# Out:
# array([8.8 , 9.18, 8.86, 8.83, 8.56, 8.96, 8.78, 8.45, 8.79, 8.81, 8.88,
#        9.07, 8.92, 8.75, 8.71, 8.86, 9.3 , 9.01, 8.97, 9.  , 8.76, 8.78,
#        9.23, 9.03, 9.13, 8.91, 8.98, 9.03, 8.86, 8.89, 8.97, 8.72, 8.93,
#        8.58, 8.94, 8.6 , 8.77, 8.81, 8.54, 8.97, 8.91, 8.68, 9.06, 8.9 ,
#        8.94, 8.91, 8.91, 8.95, 8.57, 8.82])

# %%
plt.scatter(X[y_predicted==0,0],X[y_predicted==0,1],c='red')
plt.scatter(X[y_predicted==1,0],X[y_predicted==1,1],c='blue')
plt.scatter(X[y_predicted==2,0],X[y_predicted==2,1],c='green')
plt.scatter(X[y_predicted==3,0],X[y_predicted==3,1],c='yellow')

# %% [markdown]
# # K-Means in 3-D

# %%
from sklearn.datasets import make_blobs

centroids = [(-5,-5,5),(5,2,3),(-2,-3,-5),(1,3,-3)]
cluster_std = [1,1,1,1]

X,y = make_blobs(n_samples=1000,centers=centroids,cluster_std=cluster_std,random_state=0)

# %%
import plotly.express as px
fig=px.scatter_3d(x=X[:,0],y=X[:,1],z=X[:,2])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.cluster import KMeans

wcss=[]

for i in range(1,10):
  km=KMeans(n_clusters=i,random_state=0)
  km.fit(X)
  wcss.append(km.inertia_)

wcss
# Out:
# [44627.860876623534,
#  23025.45207513671,
#  8907.055587772355,
#  2813.926863628631,
#  2651.8129217523106,
#  2502.209970525624,
#  2382.1639978575627,
#  2242.9654011458724,
#  2076.155118362126]

# %%
plt.plot(range(1,10),wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
km=KMeans(n_clusters=4,random_state=0)
y_predicted=km.fit_predict(X)
y_predicted
# Out:
# array([3, 0, 1, 3, 2, 2, 3, 2, 3, 3, 0, 3, 0, 1, 1, 3, 3, 3, 3, 1, 2, 1,
#        3, 1, 2, 2, 2, 0, 1, 2, 2, 0, 3, 0, 0, 2, 0, 2, 3, 3, 3, 1, 3, 3,
#        0, 2, 0, 0, 3, 2, 2, 0, 3, 1, 3, 0, 2, 0, 1, 0, 3, 1, 3, 3, 3, 3,
#        3, 3, 2, 3, 1, 0, 3, 0, 0, 1, 0, 3, 1, 2, 2, 1, 0, 0, 3, 1, 1, 3,
#        0, 0, 1, 3, 1, 1, 1, 1, 0, 3, 3, 0, 0, 0, 0, 0, 2, 3, 1, 3, 1, 3,
#        2, 0, 3, 0, 2, 0, 3, 1, 0, 2, 1, 3, 0, 2, 3, 3, 1, 2, 2, 2, 3, 1,
#        0, 0, 1, 0, 3, 0, 1, 0, 3, 1, 1, 3, 0, 0, 1, 3, 2, 0, 1, 3, 0, 0,
#        3, 3, 3, 0, 0, 3, 3, 2, 3, 1, 2, 3, 1, 2, 1, 1, 3, 0, 1, 3, 0, 3,
#        3, 3, 2, 2, 0, 0, 1, 2, 2, 3, 2, 1, 1, 0, 1, 3, 3, 2, 1, 0, 0, 3,
#        1, 2, 3, 1, 1, 0, 2, 0, 1, 1, 1, 1, 0, 2, 2, 0, 1, 3, 2, 1, 1, 0,
#        2, 3, 2, 1, 1, 2, 0, 0, 0, 3, 1, 3, 3, 2, 0, 1, 0, 0, 0, 0, 2, 2,
#        3, 3, 2, 2, 0, 2, 1, 1, 2, 0, 3, 3, 0, 3, 3, 0, 3, 0, 2, 0, 3, 3,
#        3, 2, 3, 2, 2, 1, 3, 1, 3, 1, 2, 2, 0, 1, 2, 0, 2, 2, 0, 3, 3, 1,
# ...

# %%
df=pd.DataFrame()

df['X']=X[:,0]
df['y']=X[:,1]
df['z']=X[:,2]
df['label']=y_predicted


fig=px.scatter_3d(df,x='X',y='y',z='z',color='label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
